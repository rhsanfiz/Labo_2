# %% [markdown]
# <a href="https://colab.research.google.com/github/rhsanfiz/Labo_2/blob/main/Fourier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

url = '/content/F0000CH1.CSV'     #Ver como subir los datos, xq de momento hay que cargar los archivos de a uno
datos = pd.read_csv(url,header=None)
#print(datos)

#t: tiempo; volt: voltaje.  Dejo el tiempo comentado xq no es necesario, solo hace falta el dt de muestreo
#t = datos[3].to_numpy()
volt = datos[4].to_numpy()

#N: cantidad de puntos    dt: diferencia temporal entre puntos
N = len(volt)
dt = float(datos[1][1])

yf = sc.fft.fft(volt)
xf = sc.fft.fftfreq(N,d=dt)[35:48]   #pongo del 35 al 48 xq es donde se ve bien la campana. cambiar por [:N//2] para todo el espectro

plt.xlabel('Frecuencia (kHz)')
plt.ylabel('???')

plt.scatter(xf, 2.0/N * np.abs(yf[35:48]))    #Ni idea xq el 2pi/N
plt.show()
# Out:
# <class 'float'>
